# %% [markdown]
# ---
# # A. Model Inference
# ---

# %% [markdown]
# ---
# ## A-1. Import Libraries

# %%
#Libraries
import pickle
import re
import string
import numpy as np
import pandas as pd
import nltk
from nltk.corpus import stopwords
from gensim.models import Word2Vec
from sklearn.metrics.pairwise import cosine_similarity
from IPython.display import display

# %% [markdown]
# ---
# ## A-2. NLTK Setup

# %%
# Setup NLTK
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Naufal\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Naufal\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# ---
# ## A-3. Inferencing

# %%
# Load stopwords dan model
indo_stopwords = set(stopwords.words('indonesian'))
model_w2v = Word2Vec.load('word2vec_model.model')
df = pd.read_pickle('skincare_df_w2v.pkl')

# Fungsi preprocessing
def preprocess_text(text):
    if pd.isna(text):
        return text
    text = re.sub(r"\\n", " ", text)
    text = re.sub(r"\s+", " ", text).strip()

    keywords = ['ingredients', 'how to use', 'suitable']
    pattern = r'(?i)([a-zA-Z0-9])(' + '|'.join([k.replace(' ', '') for k in keywords]) + r')'
    text = re.sub(pattern, lambda m: f'{m.group(1)} {m.group(2)}', text)

    text = text.lower()
    text = re.sub(r'\bx\b', '', text)
    text = re.sub(r'\b\d+\b', '', text)
    text = re.sub(r'\b\d+[a-zA-Z]+\b', '', text)
    text = text.translate(str.maketrans('', '', string.punctuation))

    satuan_umum = {'ml', 'gram', 'menit', 'pump', 'pcs'}
    text = ' '.join([word for word in text.split() if word not in satuan_umum])

    for k in keywords:
        text = re.sub(k + r'\s*:?', k, text)

    text = ' '.join([word for word in text.split() if word not in indo_stopwords])
    text = re.sub(r'\s+', ' ', text).strip()
    return text

# Fungsi rata-rata Word2Vec
def get_avg_w2v(tokens, model):
    vectors = [model.wv[w] for w in tokens if w in model.wv]
    if len(vectors) == 0:
        return np.zeros(model.vector_size)
    return np.mean(vectors, axis=0)

# Fungsi rekomendasi (format sama kayak training)
def recommended_products(query, df, model, alpha=0.7, beta=0.15, gamma=0.15, top_n=3):
    df_temp = df.copy()

    # Preprocess query
    query_clean = preprocess_text(query)
    query_tokens = query_clean.split()
    query_vec = get_avg_w2v(query_tokens, model).reshape(1, -1)
    X_vectors = np.vstack(df_temp['w2v_vector'].values)

    # Hitung cosine similarity
    cos_sim = cosine_similarity(query_vec, X_vectors)[0]
    df_temp['similarity'] = cos_sim

    # Normalisasi rating
    df_temp['rating_norm'] = (
        (df_temp['rating'] - df_temp['rating'].min()) /
        (df_temp['rating'].max() - df_temp['rating'].min())
    )

    # Normalisasi review count
    df_temp['review_norm'] = (
        (df_temp['review_count'] - df_temp['review_count'].min()) /
        (df_temp['review_count'].max() - df_temp['review_count'].min())
    )

    # Skor gabungan
    df_temp['final_score'] = (
        alpha * df_temp['similarity'] +
        beta * df_temp['rating_norm'] +
        gamma * df_temp['review_norm']
    )

    # Ambil top produk per kategori
    return (
        df_temp.sort_values(by='final_score', ascending=False)
        .groupby('product_type', group_keys=False)
        .head(top_n)
        .sort_values(by='product_type', ascending=True)
        .reset_index(drop=True)
        [['product_type', 'product', 'brand', 'price', 'rating', 'review_count',
          'description', 'image_url', 'similarity', 'final_score']]
    )

# %%
# Hasil rekomendasi
recommended_products("Banyak jerawat", df, model_w2v)
# Out:
#       product_type                                            product  \
# 0         cleanser                               Gentle Skin Cleanser
# 1         cleanser                                   Acne Facial Foam
# 2         cleanser                      Perfect Purifying Facial Foam
# 3      moisturizer                       Cerabeads Moisturising Cream
# 4      moisturizer                   Hydra Boost Oil Free Moisturizer
# 5      moisturizer                      Elixskin Nutritive Cream V2.0
# 6    serum/essence                     Chromabright Brightening Serum
# 7    serum/essence                                         Acne Serum
# 8    serum/essence              Bright Miracle Ultimate Clarity Serum
# 9   sun protection                Hydrasoothe Sunscreen Gel SPF 45+++
# 10  sun protection                        Sun Protection SPF 30 PA+++
# 11  sun protection  BiomeProtect Acne & Oil Correct Physical Sunsc...
# 12           toner                   Daily Beginner Exfoliating Toner
# 13           toner                                  Acne Series Toner
# 14           toner                            Calming Hydrating Toner
#
#                   brand     price  rating  review_count  \
# 0              Cetaphil  112000.0     4.2         15298
# 1   Nourish Beauty Care   30000.0     3.8           119
# 2      Mineral Botanica   20000.0     4.7           120
# 3          Cosmo Colony  150280.0     4.9           116
# 4             ElsheSkin  129000.0     4.7           243
# 5       Aizen Dermalogy  139000.0     4.0           120
# 6             Everwhite  125000.0     4.8          1286
# 7               Implora   35000.0     4.1           269
# 8                Pond's  108000.0     4.6          1483
# 9      Azarine Cosmetic   54000.0     4.8         14814
# 10                Emina   26000.0     3.7         15719
# 11               LABORE  185000.0     4.2           149
# 12     Azarine Cosmetic   69000.0     4.2          1972
# 13              L'Indka   95000.0     4.9           111
# 14         Natur Beauty  139000.0     4.2           161
#
#                                           description  \
# 0   Cetaphil Gentle Skin Cleanser mengandung formu...
# 1   Nourish Beauty Care (NBC) acne facial foam mem...
# 2   Mineral Botanica Perfect Purifying Facial Foam...
# 3   CO.CO Cosmo Colony Cerabeads Moisturising Crea...
# 4   ElsheSkin Hydra Boost Oil-Free Moisturizer mer...
# 5   Reformulation in November 2022Aizen Elixskin N...
# 6   Manfaat :Mencerahkan wajah,kulit bening,menyam...
# 7   Implora Acne Serum membantu untuk meminimalkan...
# 8   POND's Bright Miracle Ultimate Clarity Serum m...
# 9   DAILY SKIN PROTECTION FOR SUNSCREEN HATERSORGA...
# 10  Emina Sun Protection dengan SPF 30 dan PA+++ m...
# 11  LABORÉ Sensitive Skin Care BiomeProtect Acne &...
# 12  Smooth Flawless Clear Skin- Untuk semua jenis ...
# 13  L'Indka Acne Series Toner merupakan penyegar w...
# 14  Natur Calming Hydrating Toner merupakan toner ...
#
#                                             image_url  similarity  final_score
# 0   https://image.femaledaily.com/dyn/210/images/p...    0.544327     0.622450
# 1   https://image.femaledaily.com/dyn/210/images/p...    0.760471     0.601048
# 2   https://image.femaledaily.com/dyn/210/images/p...    0.654471     0.588221
# 3   https://s3.ap-southeast-1.amazonaws.com/assets...    0.680195     0.619826
# 4   https://image.femaledaily.com/dyn/210/images/p...    0.663392     0.595644
# 5   https://image.femaledaily.com/dyn/210/images/p...    0.730446     0.593677
# 6   https://image.femaledaily.com/dyn/210/images/p...    0.670959     0.617752
# 7   https://image.femaledaily.com/dyn/210/images/p...    0.747661     0.613973
# 8   https://s3.ap-southeast-1.amazonaws.com/assets...    0.672443     0.607043
# 9   https://image.femaledaily.com/dyn/210/images/p...    0.539390     0.655266
# 10  https://image.femaledaily.com/dyn/210/images/p...    0.540799     0.589923
# 11  https://s3.ap-southeast-1.amazonaws.com/assets...    0.635443     0.541089
# 12  https://image.femaledaily.com/dyn/210/images/p...    0.776380     0.657211
# 13  https://image.femaledaily.com/dyn/210/images/p...    0.656219     0.602995
# 14  https://image.femaledaily.com/dyn/210/images/p...    0.710137     0.593489
